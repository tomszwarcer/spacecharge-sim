# %%
import matplotlib.pyplot as plt

# %%
times = open("ion_times.txt")
l = [float(i[:-1]) for i in times.readlines()]
print(l)
plt.hist(l,bins = 40)
plt.xlabel("Fraction of time window")
plt.ylabel("Counts")
plt.title("When ions are produced in a time window")
# Out:
# [0.487655, 0.0925177, 0.860761, 0.904075, 0.657104, 0.469438, 0.124857, 0.364117, 0.634954, 0.392999, 0.276981, 0.380142, 0.853454, 0.0932725, 0.350815, 0.101094, 0.216418, 0.0762542, 0.859063, 0.436773, 0.635503, 0.38772, 0.609454, 0.337857, 0.966055, 0.622066, 0.80957, 0.046164, 0.337389, 0.162761, 0.347074, 0.57755, 0.0230804, 0.756511, 0.325054, 0.814918, 0.52023, 0.735862, 0.920004, 0.670256, 0.0672804, 0.893059, 0.7633, 0.577346, 0.627781, 0.637273, 0.0750163, 0.219446, 0.53689, 0.696489, 0.673141, 0.834041, 0.561917, 0.0716964, 0.865309, 0.125124, 0.478952, 0.946052, 0.0800932, 0.858902, 0.661536, 0.836946, 0.338069, 0.135019, 0.442728, 0.820977, 0.900321, 0.775173, 0.834327, 0.698817, 0.87561, 0.107512, 0.254282, 0.557813, 0.711903, 0.586527, 0.819824, 0.676706, 0.727857, 0.800596, 0.0488767, 0.792685, 0.956944, 0.305102, 0.662754, 0.234671, 0.182921, 0.382571, 0.74651, 0.960797, 0.326065, 0.945713, 0.828675, 0.727705, 0.495499, 0.741534, 0.710418, 0.489608, 0.676694, 0.10627
# ...
